# %%
# !pip install common
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for common: filename=common-0.1.2-py3-none-any.whl size=3715 sha256=14e8cb4c79a7db143ac66e2a7032d614561c7444113461772a42cbe708ab32f4
#   Stored in directory: c:\users\bcaid\appdata\local\pip\cache\wheels\02\4a\4c\adb3de83d3301ba00d4d30c7600792cb157ffd709658cc7a97
# Successfully built common
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install common.utils
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
energy = pd.read_csv('energy.csv')
energy.head()
# Out:
#              timestamp    load       temp
# 0  2012-01-01 00:00:00  2698.0  32.000000
# 1  2012-01-01 01:00:00  2558.0  32.666667
# 2  2012-01-01 02:00:00  2444.0  30.000000
# 3  2012-01-01 03:00:00  2402.0  31.000000
# 4  2012-01-01 04:00:00  2403.0  32.000000

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# Now, plot the first week of July 2014, by providing it as input to the `energy` in `[from date]: [to date]` pattern:

# %%
# Selecting the subset of data for July 1-7, 2014
subset = energy.loc['2011-07-01':'2012-07-07']

subset.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()
subset.head()
# Out:
#                  timestamp    load       temp
# 20110  2014-04-17 22:00:00  3093.0  34.666667
# 20111  2014-04-17 23:00:00  2831.0  32.000000
# 20112  2014-04-18 00:00:00  2671.0  31.666667
# 20113  2014-04-18 01:00:00  2587.0  30.000000
# 20114  2014-04-18 02:00:00  2569.0  28.333333
